# %% [markdown]
# # Exploratory Data Analysis (EDA) on Netflix Dataset
#
# ## Objective
# To perform Exploratory Data Analysis (EDA) on the Netflix Titles dataset using NumPy and Pandas and gain useful insights from the dataset.

# %% [markdown]
# # Introduction to NumPy
#
# NumPy (Numerical Python) is a Python library used for numerical computations. It supports arrays, mathematical operations, statistical functions, and probability calculations.
#
# ### Features of NumPy
# - Multi-dimensional arrays
# - Fast calculations
# - Statistical functions
# - Mathematical operations
#
# ---
#
# # Introduction to Pandas
#
# Pandas is a Python library used for data manipulation and analysis. It helps in reading CSV files, cleaning datasets, filtering data, and statistical analysis.
#
# ### Features of Pandas
# - Read CSV files
# - Handle missing values
# - Data filtering
# - Grouping and aggregation
# - Statistical summaries
#
# ---
#
# # What is Exploratory Data Analysis (EDA)?
#
# EDA is the process of analyzing datasets to understand their structure, identify patterns, and extract useful insights.
#
# EDA helps to:
# - Understand dataset structure
# - Find missing values
# - Analyze statistics
# - Visualize patterns in data

# %% [markdown]
# # Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Netflix Dataset

# %%
df = pd.read_csv("netflix_titles.csv")

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %% [markdown]
# # Display First 5 Rows

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # Display Last 5 Rows

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# # Display Random 5 Rows

# %%
df.sample(5)
# Out:
#      show_id   type                                              title  \
# 846     s847  Movie                                               Home
# 1981   s1982  Movie                                            Whipped
# 6888   s6889  Movie                                        Gran Torino
# 1124   s1125  Movie                                       Maximum Risk
# 2858   s2859  Movie  Calico Critters: Everyone's Big Dream Flying i...
#
#             director                                               cast  \
# 846      Tim Johnson  Jim Parsons, Rihanna, Steve Martin, Jennifer L...
# 1981    Chandra Liow  Andovi da Lopez, Jovial da Lopez, Chandra Liow...
# 6888  Clint Eastwood  Clint Eastwood, Bee Vang, Ahney Her, Christoph...
# 1124       Ringo Lam  Jean-Claude Van Damme, Natasha Henstridge, Jea...
# 2858   Momoko Kamiya                                    Erika Harlacher
#
#                      country          date_added  release_year rating  \
# ...

# %% [markdown]
# # Shape of Dataset

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# # Column Names

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='str')

# %% [markdown]
# # Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 825.8 KB

# %% [markdown]
# # Check Missing Values

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# # NumPy Statistical Analysis

# %%
years = df['release_year'].to_numpy()

print("Mean:", np.mean(years))
print("Median:", np.median(years))
print("Maximum:", np.max(years))
print("Minimum:", np.min(years))
print("Standard Deviation:", np.std(years))
# Out:
# Mean: 2014.1801975701146
# Median: 2017.0
# Maximum: 2021
# Minimum: 1925
# Standard Deviation: 8.818811417623195

# %% [markdown]
# # Movies vs TV Shows Distribution

# %%
df['type'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.title("Movies vs TV Shows")
plt.show()

# %% [markdown]
# # Release Year Distribution

# %%
df['release_year'].hist()

plt.title("Release Year Distribution")
plt.xlabel("Release Year")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# # Release Year Skewness

# %%
df['release_year'].skew()
# Out:
# np.float64(-3.4465650403316013)

# %% [markdown]
# # Top Content Ratings

# %%
df['rating'].value_counts().head(10).plot(
    kind='bar'
)

plt.title("Top Ratings")
plt.show()

# %% [markdown]
# # Top 10 Countries

# %%
df['country'].value_counts().head(10).plot(
    kind='bar'
)

plt.title("Top 10 Countries")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # Boxplot for Release Year

# %%
sns.boxplot(x=df['release_year'])

plt.show()

# %% [markdown]
# # Count Plot by Content Type

# %%
sns.countplot(
    x='type',
    data=df
)

plt.show()

# %% [markdown]
# # Release Year by Type

# %%
sns.boxplot(
    x='type',
    y='release_year',
    data=df
)

plt.show()

# %% [markdown]
# # Ratings by Content Type

# %%
sns.countplot(
    x='rating',
    hue='type',
    data=df
)

plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# # Movies Only

# %%
movies = df[df['type'] == 'Movie']

movies.head()
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                                 NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# ...

# %% [markdown]
# # TV Shows Only

# %%
tvshows = df[df['type'] == 'TV Show']

tvshows.head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %% [markdown]
# # Average Release Year by Type

# %%
df.groupby('type')['release_year'].mean()
# Out:
# type
# Movie      2013.121514
# TV Show    2016.605755
# Name: release_year, dtype: float64

# %% [markdown]
# # Correlation Matrix

# %%
df.corr(numeric_only=True)
# Out:
#               release_year
# release_year           1.0

# %% [markdown]
# # Outlier Detection using Boxplot

# %%
sns.boxplot(x=df['release_year'])

plt.show()

# %% [markdown]
# # Outlier Detection using IQR Method

# %%
Q1 = df['release_year'].quantile(0.25)
Q3 = df['release_year'].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - (1.5 * IQR)
upper_limit = Q3 + (1.5 * IQR)

outliers = df[
    (df['release_year'] < lower_limit) |
    (df['release_year'] > upper_limit)
]

outliers
# Out:
#      show_id   type              title          director  \
# 7         s8  Movie            Sankofa      Haile Gerima
# 22       s23  Movie    Avvai Shanmughi    K.S. Ravikumar
# 24       s25  Movie              Jeans        S. Shankar
# 26       s27  Movie     Minsara Kanavu       Rajiv Menon
# 41       s42  Movie               Jaws  Steven Spielberg
# ...      ...    ...                ...               ...
# 8764   s8765  Movie         Wyatt Earp   Lawrence Kasdan
# 8766   s8767  Movie                XXx         Rob Cohen
# 8768   s8769  Movie  Y Tu Mamá También    Alfonso Cuarón
# 8770   s8771  Movie            Yaadein      Subhash Ghai
# 8792   s8793  Movie        Young Tiger            Mu Chu
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 22    Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...

# %% [markdown]
# # Conclusion
#
# In this task, I performed Exploratory Data Analysis (EDA) on the Netflix Titles dataset using NumPy and Pandas. I analyzed the dataset structure, checked missing values, performed statistical analysis, and visualized patterns using graphs. I also conducted univariate and bivariate analysis and detected outliers using the IQR method. This task improved my understanding of data analysis and visualization in Python.
